# %%
'''
Challenge:
Change the code from DUDL_regular_minibatch, and set the mini-batch size to 2^n for N=1,...,6.
Set the learning rate to 0.001.

Store the resulting train and test accuracy over epochs, for each bacth size.

'''
# Out:
# '\nChallenge:\nChange the code from DUDL_regular_minibatch, and set the mini-batch size to 2^n for N=1,...,6.\nSet the learning rate to 0.001.\n\nStore the resulting train and test accuracy over epochs, for each bacth size.\n\n'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
display.set_matplotlib_formats('svg')

# libraries for partitioning and batching the data
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader,TensorDataset
# Out:
# /var/folders/qm/y3ntm4w54lv2x8p86n_p1ml80000gn/T/ipykernel_24269/154944603.py:7: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg')

# %%
# import dataset (comes with seaborn)
import seaborn as sns
iris = sns.load_dataset('iris')

# %%
# organize the data

# convert pandas dataframe to tensor
data = torch.tensor(iris[iris.columns[:4]].values).float()

# trnasform species to number
labels = torch.zeros(len(data),dtype=torch.long)
# labels[iris.species=='setosa'] = 0 # dont need
labels[iris.species=='versicolor'] = 1
labels[iris.species=='virginica'] = 2

# %%
# use scikitlearn to split the data
train_data,test_data,train_labels,test_labels = train_test_split(data,labels,train_size=20)

# Convert them into Pytorch datasets (note: alread converted to tensors)
train_dataDataset = TensorDataset(train_data,train_labels)
test_dataDataset = TensorDataset(test_data,test_labels)

# converted to dataloaders later !

# %% [markdown]
# ## ANN MODEL

# %%
# a function that creates the ANN model

def createANewModel():
    
    # model architecture
    ANNiris = nn.Sequential(
        nn.Linear(4,64),    # input layer
        nn.ReLU(),          # activation unit
        nn.Linear(64,64),   # hidden layer
        nn.ReLU(),          # activation unit   
        nn.Linear(64,3),    # output units
        #nn.softmax(dim=1)  # final activation unit
    )
    
    # loss function
    lossfun = nn.CrossEntropyLoss()
    
    # optimizer
    optimizer = optim.SGD(ANNiris.parameters(),lr=.001)
    
    return ANNiris,lossfun,optimizer

# %%
# train the model

# global parameter
numepochs = 500

def trainTheModel():
    
    # initialize accuracies as empties
    trainAcc = []
    testAcc = []
    losses = []
    
    # loop over epochs
    for epochi in range(numepochs):
        
        # activate training mode
        ANNiris.train()
        
        # loop over training data batches
        batchAcc = []
        batchLoss = []
        for X,y in train_loader:
            
            # forward pass and loss
            yHat = ANNiris(X)
            loss = lossfun(yHat,y)
            
            # backprop
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            # compute training accuracy just for this batch
            batchAcc.append(100*torch.mean((torch.argmax(yHat,axis=1)==y).float()).item())
            batchLoss.append(loss.item())
        # end of batch loop
        
        # now that we have trained through the batches, get their average training accuracy
        trainAcc.append(np.mean(batchAcc))
        losses.append(np.mean(batchLoss))
        
        # test accuracy
        
        # extract X,y from test dataloader
        X,y = next(iter(test_loader))
        
        # activate testing mode
        ANNiris.eval()
        with torch.no_grad():
            predlabels = torch.argmax(ANNiris(X),axis=1)
        
        # compute accuracy
        testAcc.append(100*torch.mean((predlabels==y).float()).item())
    
    # function output
    return trainAcc,testAcc,losses

# %% [markdown]
# ## Run the experiment and visualize the results

# %%
# range of batch sizes
batchsizes = 2**np.arange(1,7)

# initialize output results matrices
accuracyResultsTrain = np.zeros((numepochs,len(batchsizes)))
accuracyResultsTest = np.zeros((numepochs,len(batchsizes)))

# test data doesnot vary by training batch size
test_loader = DataLoader(test_dataDataset,batch_size=test_dataDataset.tensors[0].shape[0])

# loop over batch sizes
for bi in range(len(batchsizes)):
    
    # create dataloader object
    train_loader = DataLoader(train_dataDataset,batch_size=int(batchsizes[bi]),shuffle=True,drop_last=True)
    
    # create and train a model
    ANNiris,lossfun,optimizer = createANewModel()
    trainAcc,testAcc,losses = trainTheModel()
    
    # store data
    accuracyResultsTrain[:,bi]=trainAcc
    accuracyResultsTest[:,bi]=testAcc
# Out:
# /Users/pratik18/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/pratik18/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
# plot some results

fig,ax = plt.subplots(1,2,figsize=(16,6))

ax[0].plot(accuracyResultsTrain)
ax[0].set_title('Train Accuracy')
ax[1].plot(accuracyResultsTest)
ax[1].set_title('Test Accuracy')

# common features
for i in range(2):
    ax[i].legend(batchsizes)
    ax[i].set_xlabel('Epoch')
    ax[i].set_ylabel('Accuracy (%)')
    ax[i].set_ylim([50,101])
    ax[i].grid()

# %%
'''
Observation:
When all the data samples are pretty similar to each other, the model learns pretty well
from each individual data sample. Each sample, each data point is really informative.

And in other cases when the data samples are much more different from each other, then you
often see the reverse. The larger batch sizes will generally give better performance and the
model will learn faster. This is something more common in computer vision and image processing.

In pictures of cats, you see the cats look really different in terms of the pixels values.
While in case of iris dataset, the data is more homogeneous.

The small mini-batches allow the model to learn really faster. While the large batches give
monotonic effect.
'''
